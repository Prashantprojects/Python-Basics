# %% [markdown]
# In this notebook the following subjects with their function will be explained
#
# - Tuple
# - Set
# - Dictionary

# %% [markdown]
# **Tuple**

# %% [markdown]
# Tuple
# Tuples are used to store multiple items in a single variable.
#
# Tuple is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Set, and Dictionary, all with different qualities and usage.
#
# A tuple is a collection which is ordered and unchangeable.
#
# Tuples are written with round brackets.

# %%
l = [4,5,6,"prashant"]
type (l)
# Out:
# list

# %%
t = (1,2,3,4,5,"prash", 4.56,4+8j)
type(t)
print(t)
# Out:
# (1, 2, 3, 4, 5, 'prash', 4.56, (4+8j))

# %%
# acces item in tuple
t = (1,2,3,4,5,"prash", 4.56,4+8j)

print(t)
print(t[::-11])
t[0]
# Out:
# (1, 2, 3, 4, 5, 'prash', 4.56, (4+8j))
# ((4+8j),)
# 1

# %%
# how many items are in the tuple
len(t)
# Out:
# 8

# %%
# show items in tuple
t = (4,5,6,"prash")

for i in t:
    print(i)
# Out:
# 4
# 5
# 6
# prash

# %%
# tuple = imumutable so you can not repalce values in a tuple
t = (4,5,6,"prash")

t[0]="bhiekhemsing"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-46f3efd06e9f> in <module>
#       2 t = (4,5,6,"prash")
#       3
# ----> 4 t[0]="bhiekhemsing"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# tuple = imumutable so you can not repalce values in a tuple
t = (3,4,5,6,7)

for i in t:
    print(t)
# Out:
# (3, 4, 5, 6, 7)
# (3, 4, 5, 6, 7)
# (3, 4, 5, 6, 7)
# (3, 4, 5, 6, 7)
# (3, 4, 5, 6, 7)

# %%
# loop through items in tuple
t = (3,4,5,6,7)

for i in range(len(t)):
    print(t[i])
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
# loop through items in list
l = [3,4,5,6,7]

for i in range(len(t)):
    print(t[i])
# Out:
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# **count()**

# %%
# count how many times an item occurs in tuple
t = (3,3,4,5,6,7)

t.count(3)
# Out:
# 2

# %% [markdown]
# **index()**

# %%
# index in tuple
t = (3,3,4,5,6,7)

t.index(3)
# Out:
# 0

# %%
# concat in tuple
t = (2,4,5,6)
t1 = (6,7,8,9)

t+t1
# Out:
# (2, 4, 5, 6, 6, 7, 8, 9)

# %% [markdown]
# **insert()**

# %%
# convert tuple to a list
t = (4,5,6,7)

t = list(t)

t.insert(2,"prash")
t

#convert list to tuple
tuple(t)
# Out:
# (4, 5, 'prash', 6, 7)

# %% [markdown]
# **set**

# %% [markdown]
# Sets are used to store multiple items in a single variable.
#
# Set is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Tuple, and Dictionary, all with different qualities and usage.
#
# A set is a collection which is both unordered and unindexed.
#
# Sets are written with curly brackets.

# %%
# set is a collection which always keep unique values
s = set([1,2,3,4,5,3,3,3,3,3,3,3,4,1,1])
s
# Out:
# {1, 2, 3, 4, 5}

# %%
# set is a collection which always keep unique values
s = set([1,2,3,4,5,3,3,3,3,3,3,3,4,1,1, "prash","prash"])
s
# Out:
# {1, 2, 3, 4, 5, 'prash'}

# %%
# set is a collection which always keep unique values
s = set([1,2,3,4,5,3,3,3,3,3,3,3,4,1,1, "prash","Prash"])
s
# Out:
# {1, 2, 3, 4, 5, 'Prash', 'prash'}

# %%
# acces itmes in set
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-f68e2466456e> in <module>
#       1 # acces itmes in set
# ----> 2 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
# loop through items in set
s = set([1,2,3,4,5,3,3,3,3,3,3,3,4,1,1, "prash","Prash"])

for i in s:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# Prash
# prash

# %%
type(s)
# Out:
# set

# %%
s = {4,5,6,7,3,4,7,5,4,1,2,0, "prashant", "bhiekhemsing"}
s
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 'bhiekhemsing', 'prashant'}

# %%
s = {4,5,6,7,3,4,7,5,4,1,2,0,5656,4564,234,234,2342,"abc","##","prashant", "bhiekhemsing"}
s
# Out:
# {'##',
#  0,
#  1,
#  2,
#  234,
#  2342,
#  3,
#  4,
#  4564,
#  5,
#  5656,
#  6,
#  7,
#  'abc',
#  'bhiekhemsing',
#  'prashant'}

# %%
for i in s:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 2342
# abc
# 234
# ##
# bhiekhemsing
# 4564
# 5656
# prashant

# %% [markdown]
# **Dictionary**

# %% [markdown]
# Dictionaries are used to store data values in key:value pairs.
#
# A dictionary is a collection which is ordered*, changeable and does not allow duplicates.

# %%
d = {}
type(d)
# Out:
# dict

# %%
d = {"name":"Prashant", "surname":"bhiekhemsing"}

# %%
d
# Out:
# {'name': 'Prashant', 'surname': 'bhiekhemsing'}

# %%
# Types that are allowed in a dictionary
d = {"key":[1,2,3,4,5,[345,45]],"key1":(3,3,4,5,6),"key 2":{3,4,5,6}, "key 3":{'x':"sf","y":"d"}}
d
# Out:
# {'key': [1, 2, 3, 4, 5, [345, 45]],
#  'key1': (3, 3, 4, 5, 6),
#  'key 2': {3, 4, 5, 6},
#  'key 3': {'x': 'sf', 'y': 'd'}}

# %%
# acces items in a key
d['key']
# Out:
# [1, 2, 3, 4, 5, [345, 45]]

# %%
# acces items in a key
for i in d:
    print(d[i])
# Out:
# [1, 2, 3, 4, 5, [345, 45]]
# (3, 3, 4, 5, 6)
# {3, 4, 5, 6}
# {'x': 'sf', 'y': 'd'}

# %%
d['key 3']['y']
# Out:
# 'd'

# %%
# acces items in a key
for i in d:
    print(i,d[i])
# Out:
# key [1, 2, 3, 4, 5, [345, 45]]
# key1 (3, 3, 4, 5, 6)
# key 2 {3, 4, 5, 6}
# key 3 {'x': 'sf', 'y': 'd'}

# %% [markdown]
# **keys()**

# %%
d.keys()
# Out:
# dict_keys(['key', 'key1', 'key 2', 'key 3'])

# %%
for i in d.keys():
    print(d[i])
# Out:
# [1, 2, 3, 4, 5, [345, 45]]
# (3, 3, 4, 5, 6)
# {3, 4, 5, 6}
# {'x': 'sf', 'y': 'd'}

# %% [markdown]
# **values()**

# %%
d.values()
# Out:
# dict_values([[1, 2, 3, 4, 5, [345, 45]], (3, 3, 4, 5, 6), {3, 4, 5, 6}, {'x': 'sf', 'y': 'd'}])

# %%
for i in d.values():
    print(i)
# Out:
# [1, 2, 3, 4, 5, [345, 45]]
# (3, 3, 4, 5, 6)
# {3, 4, 5, 6}
# {'x': 'sf', 'y': 'd'}

# %% [markdown]
# **append()**

# %%
m = []

d = {"key":[1,2,3,4,5,[345,45]],"key1":(3,3,4,5,6),"key 2":{3,4,5,6}, "key 3":{'x':"sf","y":"d"}}

for i in d.values():
    if type(i) == tuple:
        for j in i:
            m.append(j)
            
m
# Out:
# [3, 3, 4, 5, 6]

# %%
# add new keys to dictionary
d["key5"] = "4,5,6,6"

# %%
d
# Out:
# {'key': [1, 2, 3, 4, 5, [345, 45]],
#  'key1': (3, 3, 4, 5, 6),
#  'key 2': {3, 4, 5, 6},
#  'key 3': {'x': 'sf', 'y': 'd'},
#  'key5': '4,5,6,6'}

# %%
# create a dictionary from 0 - 10 with values ^2
d = {}
for i in range(10):
    d[i] = i**2

d
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# **isupper()**

# %%
l = ['prashant', 'bhiekhemsing','zyz', 'abc']

d = {}
for i in l:
    d[i] = i.upper()

d
# Out:
# {'prashant': 'PRASHANT',
#  'bhiekhemsing': 'BHIEKHEMSING',
#  'zyz': 'ZYZ',
#  'abc': 'ABC'}

# %%
l = ['prashant', 'bhiekhemsing','zyz', 'abc']

d = {}
for i in l:
    d[i] = i.isupper()

d
# Out:
# {'prashant': False, 'bhiekhemsing': False, 'zyz': False, 'abc': False}

# %%
d = {}
for i in range(10):
    d[i] = i**2

d
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
# comprehension method
{ i:i**2 for i in range(10)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
l = ['prashant', 'bhiekhemsing','zyz', 'abc']

d = {}
for i in l:
    d[i] = i.isupper()

d
# Out:
# {'prashant': False, 'bhiekhemsing': False, 'zyz': False, 'abc': False}

# %% [markdown]
# **items**()

# %%
d = {"key":[1,2,3,4,5,[345,45]],"key1":(3,3,4,5,6),"key 2":{3,4,5,6}, "key 3":{'x':"sf","y":"d"}}

d.items()
# Out:
# dict_items([('key', [1, 2, 3, 4, 5, [345, 45]]), ('key1', (3, 3, 4, 5, 6)), ('key 2', {3, 4, 5, 6}), ('key 3', {'x': 'sf', 'y': 'd'})])
